# %%
# %matplotlib inline

import glob
from platform import python_version
import pandas as pd
import matplotlib
import numpy as np
import sklearn
import torch
import matplotlib.pyplot as plt

# %%
print("python version==%s" % python_version())
print("pandas==%s" % pd.__version__)
print("numpy==%s" % np.__version__)
print("sklearn==%s" % sklearn.__version__)
print("torch==%s" % torch.__version__)
print("matplotlib==%s" % matplotlib.__version__)
# Out:
# python version==3.8.10
# pandas==1.5.1
# numpy==1.23.4
# sklearn==1.1.3
# torch==1.13.0+cu117
# matplotlib==3.6.2

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)
# Out:
# Using device: cuda

# %%
#load data
data = pd.read_csv("..\..\..\Data\Day\S&P 500 Historical Data00-20.csv")

# %%
#transform data
data = data.replace(",", "", regex=True)
data.Date = pd.to_datetime(data.Date)
data = data.sort_values(by=["Date"])
data.set_index('Date')
data.Price = data.Price.astype(float)
data.High = data.High.astype(float)
data.Low = data.Low.astype(float)
data.Open = data.Open.astype(float)
data["Vol."] = data["Vol."].astype(float)

# %%
data.head()
# Out:
#            Date   Price    Open    High     Low  Vol. Change %
# 4999 2000-01-03  1455.2  1469.2  1478.0  1438.4   NaN   -0.95%
# 4998 2000-01-04  1399.4  1455.2  1455.2  1397.4   NaN   -3.83%
# 4997 2000-01-05  1402.1  1399.4  1413.3  1377.7   NaN    0.19%
# 4996 2000-01-06  1403.5  1402.1  1411.9  1392.0   NaN    0.10%
# 4995 2000-01-07  1441.5  1403.5  1441.5  1400.5   NaN    2.71%

# %%
data.index = data.index[::-1]

# %%
data.head()
# Out:
#         Date   Price    Open    High     Low  Vol. Change %
# 0 2000-01-03  1455.2  1469.2  1478.0  1438.4   NaN   -0.95%
# 1 2000-01-04  1399.4  1455.2  1455.2  1397.4   NaN   -3.83%
# 2 2000-01-05  1402.1  1399.4  1413.3  1377.7   NaN    0.19%
# 3 2000-01-06  1403.5  1402.1  1411.9  1392.0   NaN    0.10%
# 4 2000-01-07  1441.5  1403.5  1441.5  1400.5   NaN    2.71%

# %%
special_data = data[(data['Date'] > '2010-01-01') & (data['Date'] < '2015-01-01')]
special_data.index = data.index[:len(special_data)]

# %%
special_data.head(10)
# Out:
#               Price
# Date
# 2010-01-04  1132.99
# 2010-01-05  1136.52
# 2010-01-06  1137.14
# 2010-01-07  1141.69
# 2010-01-08  1144.98
# 2010-01-11  1146.98
# 2010-01-12  1136.22
# 2010-01-13  1145.68
# 2010-01-14  1148.46
# 2010-01-15  1136.03

# %%
#change indexes
special_data.set_index('Date', inplace=True)

# %%
special_data = special_data.drop(columns=['Open', 'High', 'Low', 'Vol.', 'Change %'])

# %%
special_data.head()
# Out:
#               Price
# Date
# 2010-01-04  1132.99
# 2010-01-05  1136.52
# 2010-01-06  1137.14
# 2010-01-07  1141.69
# 2010-01-08  1144.98

# %%
plt.plot(special_data)

# %%
from torch.autograd import Variable
from sklearn.preprocessing import MinMaxScaler

def sliding_windows(data, seq_length):
    x = []
    y = []

    for i in range(len(data)-seq_length-1):
        _x = data[i:(i+seq_length)]
        _y = data[i+seq_length]
        x.append(_x)
        y.append(_y)

    return np.array(x),np.array(y)

sc = MinMaxScaler()
training_data = sc.fit_transform(special_data)

seq_length = 100
x, y = sliding_windows(training_data, seq_length)

train_size = int(len(y) * 0.7)
val_size = 100
test_size = len(y) - train_size - val_size

dataX = Variable(torch.Tensor(np.array(x)).to(device))
dataY = Variable(torch.Tensor(np.array(y)).to(device))

trainX = Variable(torch.Tensor(np.array(x[0:train_size])).to(device))
trainY = Variable(torch.Tensor(np.array(y[0:train_size])).to(device))

testX = Variable(torch.Tensor(np.array(x[train_size:(len(x) - val_size)])).to(device))
testY = Variable(torch.Tensor(np.array(y[train_size:(len(y) - val_size)])).to(device))

valX = Variable(torch.Tensor(np.array(x[(len(x) - val_size):len(x)])).to(device))
valY = Variable(torch.Tensor(np.array(y[(len(x) - val_size):len(y)])).to(device))

# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

class TimeSeriesDataset(Dataset):
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __len__(self):
        return len(self.x)

    def __getitem__(self, idx):
        return self.x[idx], self.y[idx]

train_dataset = TimeSeriesDataset(trainX, trainY)
test_dataset = TimeSeriesDataset(testX, testY)
val_dataset = TimeSeriesDataset(valX, valY)

train_loader = DataLoader(train_dataset, batch_size = 64, shuffle = False)
test_loader = DataLoader(test_dataset, batch_size = 64, shuffle = False)
val_loader = DataLoader(val_dataset, batch_size = 64, shuffle = False)

# %%
import torch.nn as nn

class LSTM(nn.Module):

    def __init__(self, num_classes, input_size, hidden_size, num_layers):
        super(LSTM, self).__init__()
        
        self.num_classes = num_classes
        self.num_layers = num_layers
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.seq_length = seq_length
        
        self.lstm = nn.LSTM(input_size = input_size, hidden_size = hidden_size,
                            num_layers = num_layers, batch_first=True)
        
        self.fc = nn.Linear(hidden_size, num_classes)

    def forward(self, x):
        h_0 = Variable(torch.zeros(
            self.num_layers, x.size(0), self.hidden_size).to(device))
        
        c_0 = Variable(torch.zeros(
            self.num_layers, x.size(0), self.hidden_size).to(device))
        
        # Propagate input through LSTM
        ula, (h_out, _) = self.lstm(x, (h_0, c_0))
        
        h_out = h_out.view(-1, self.hidden_size)
        
        out = self.fc(h_out)
        
        return out

# %%
num_epochs = 1100
learning_rate = 0.001

input_size = 1
hidden_size = 64 # need to find correct value; 40 small, 64 norm, 100 a lot
num_layers = 1

num_classes = 1

model = LSTM(num_classes, input_size, hidden_size, num_layers).to(device)

# Define loss and optimizer
criterion = torch.nn.MSELoss()    # mean-squared error for regression
optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate)
#optimizer = torch.optim.SGD(lstm.parameters(), lr = learning_rate)

train_loss = []
valid_loss = []

for epoch in range(num_epochs):
    # set the model to train mode
    model.train()

    # forward pass
    output = model(trainX)
    loss = criterion(output, trainY)

    # backward pass and optimize
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    # calculate training loss
    train_loss.append(loss.item())

    # set the model to evaluation mode
    model.eval()

    # calculate validation loss
    with torch.no_grad():
        output = model(testX)
        loss = criterion(output, testY)
        valid_loss.append(loss.item())

    # print progress
    if epoch % 10 == 0:
        print('Epoch [{}/{}], Train Loss: {:.4f}, Valid Loss: {:.4f}'.format(
            epoch+1, num_epochs, train_loss[-1], valid_loss[-1]))

# plot train and validation loss
plt.plot(train_loss, label='Train Loss')
plt.plot(valid_loss, label='Validation Loss')
plt.legend()
plt.show()
# Out:
# Epoch [1/1100], Train Loss: 0.0719, Valid Loss: 0.4563
# Epoch [11/1100], Train Loss: 0.0236, Valid Loss: 0.2357
# Epoch [21/1100], Train Loss: 0.0216, Valid Loss: 0.1396
# Epoch [31/1100], Train Loss: 0.0177, Valid Loss: 0.1808
# Epoch [41/1100], Train Loss: 0.0162, Valid Loss: 0.1557
# Epoch [51/1100], Train Loss: 0.0141, Valid Loss: 0.1075
# Epoch [61/1100], Train Loss: 0.0109, Valid Loss: 0.0758
# Epoch [71/1100], Train Loss: 0.0040, Valid Loss: 0.1580
# Epoch [81/1100], Train Loss: 0.0062, Valid Loss: 0.0918
# Epoch [91/1100], Train Loss: 0.0032, Valid Loss: 0.0078
# Epoch [101/1100], Train Loss: 0.0021, Valid Loss: 0.0481
# Epoch [111/1100], Train Loss: 0.0016, Valid Loss: 0.1106
# Epoch [121/1100], Train Loss: 0.0013, Valid Loss: 0.0522
# Epoch [131/1100], Train Loss: 0.0011, Valid Loss: 0.0250
# Epoch [141/1100], Train Loss: 0.0009, Valid Loss: 0.0205
# Epoch [151/1100], Train Loss: 0.0008, Valid Loss: 0.0124
# Epoch [161/1100], Train Loss: 0.0007, Valid Loss: 0.0058
# Epoch [171/1100], Train Loss: 0.0006, Valid Loss: 0.0030
# Epoch [181/1100], Train Loss: 0.0005, Valid Loss: 0.0012
# Epoch [191/1100], Train Loss: 0.0005, Valid Loss: 0.0004
# Epoch [201/1100], Train Loss: 0.0005, Valid Loss: 0.0004
# Epoch [211/1100], Train Loss: 0.0005, Valid Loss: 0.0006
# Epoch [221/1100], Train Loss: 0.0005, Valid Loss: 0.0008
# Epoch [231/1100], Train Loss: 0.0005, Valid Loss: 0.0008
# Epoch [241/1100], Train Loss: 0.0005, Valid Loss: 0.0008
# Epoch [251/1100], Train Loss: 0.0005, Valid Loss: 0.0007
# Epoch [261/1100], Train Loss: 0.0005, Valid Loss: 0.0007
# Epoch [271/1100], Train Loss: 0.0005, Valid Loss: 0.0007
# Epoch [281/1100], Train Loss: 0.0005, Valid Loss: 0.0007
# Epoch [291/1100], Train Loss: 0.0004, Valid Loss: 0.0007
# Epoch [301/1100], Train Loss: 0.0004, Valid Loss: 0.0007
# Epoch [311/1100], Train Loss: 0.0004, Valid Loss: 0.0007
# Epoch [321/1100], Train Loss: 0.0004, Valid Loss: 0.0007
# Epoch [331/1100], Train Loss: 0.0004, Valid Loss: 0.0007
# Epoch [341/1100], Train Loss: 0.0004, Valid Loss: 0.0007
# Epoch [351/1100], Train Loss: 0.0004, Valid Loss: 0.0007
# Epoch [361/1100], Train Loss: 0.0004, Valid Loss: 0.0007
# Epoch [371/1100], Train Loss: 0.0004, Valid Loss: 0.0007
# Epoch [381/1100], Train Loss: 0.0004, Valid Loss: 0.0007
# Epoch [391/1100], Train Loss: 0.0004, Valid Loss: 0.0006
# Epoch [401/1100], Train Loss: 0.0004, Valid Loss: 0.0006
# Epoch [411/1100], Train Loss: 0.0004, Valid Loss: 0.0006
# Epoch [421/1100], Train Loss: 0.0004, Valid Loss: 0.0006
# Epoch [431/1100], Train Loss: 0.0004, Valid Loss: 0.0006
# Epoch [441/1100], Train Loss: 0.0004, Valid Loss: 0.0006
# Epoch [451/1100], Train Loss: 0.0004, Valid Loss: 0.0006
# Epoch [461/1100], Train Loss: 0.0004, Valid Loss: 0.0006
# Epoch [471/1100], Train Loss: 0.0004, Valid Loss: 0.0006
# Epoch [481/1100], Train Loss: 0.0004, Valid Loss: 0.0005
# Epoch [491/1100], Train Loss: 0.0004, Valid Loss: 0.0005
# Epoch [501/1100], Train Loss: 0.0004, Valid Loss: 0.0005
# Epoch [511/1100], Train Loss: 0.0004, Valid Loss: 0.0005
# Epoch [521/1100], Train Loss: 0.0004, Valid Loss: 0.0005
# Epoch [531/1100], Train Loss: 0.0004, Valid Loss: 0.0005
# Epoch [541/1100], Train Loss: 0.0004, Valid Loss: 0.0005
# Epoch [551/1100], Train Loss: 0.0004, Valid Loss: 0.0005
# Epoch [561/1100], Train Loss: 0.0004, Valid Loss: 0.0005
# Epoch [571/1100], Train Loss: 0.0004, Valid Loss: 0.0004
# Epoch [581/1100], Train Loss: 0.0004, Valid Loss: 0.0004
# Epoch [591/1100], Train Loss: 0.0004, Valid Loss: 0.0004
# Epoch [601/1100], Train Loss: 0.0004, Valid Loss: 0.0004
# Epoch [611/1100], Train Loss: 0.0004, Valid Loss: 0.0004
# Epoch [621/1100], Train Loss: 0.0004, Valid Loss: 0.0004
# Epoch [631/1100], Train Loss: 0.0004, Valid Loss: 0.0004
# Epoch [641/1100], Train Loss: 0.0004, Valid Loss: 0.0004
# Epoch [651/1100], Train Loss: 0.0004, Valid Loss: 0.0004
# Epoch [661/1100], Train Loss: 0.0004, Valid Loss: 0.0004
# Epoch [671/1100], Train Loss: 0.0004, Valid Loss: 0.0004
# Epoch [681/1100], Train Loss: 0.0004, Valid Loss: 0.0004
# Epoch [691/1100], Train Loss: 0.0004, Valid Loss: 0.0004
# Epoch [701/1100], Train Loss: 0.0004, Valid Loss: 0.0003
# Epoch [711/1100], Train Loss: 0.0004, Valid Loss: 0.0003
# Epoch [721/1100], Train Loss: 0.0004, Valid Loss: 0.0003
# Epoch [731/1100], Train Loss: 0.0004, Valid Loss: 0.0003
# Epoch [741/1100], Train Loss: 0.0004, Valid Loss: 0.0003
# Epoch [751/1100], Train Loss: 0.0004, Valid Loss: 0.0003
# Epoch [761/1100], Train Loss: 0.0004, Valid Loss: 0.0003
# Epoch [771/1100], Train Loss: 0.0004, Valid Loss: 0.0003
# Epoch [781/1100], Train Loss: 0.0004, Valid Loss: 0.0003
# Epoch [791/1100], Train Loss: 0.0004, Valid Loss: 0.0003
# Epoch [801/1100], Train Loss: 0.0004, Valid Loss: 0.0003
# Epoch [811/1100], Train Loss: 0.0004, Valid Loss: 0.0003
# Epoch [821/1100], Train Loss: 0.0003, Valid Loss: 0.0003
# Epoch [831/1100], Train Loss: 0.0003, Valid Loss: 0.0003
# Epoch [841/1100], Train Loss: 0.0003, Valid Loss: 0.0003
# Epoch [851/1100], Train Loss: 0.0003, Valid Loss: 0.0003
# Epoch [861/1100], Train Loss: 0.0003, Valid Loss: 0.0003
# Epoch [871/1100], Train Loss: 0.0003, Valid Loss: 0.0003
# Epoch [881/1100], Train Loss: 0.0003, Valid Loss: 0.0003
# Epoch [891/1100], Train Loss: 0.0003, Valid Loss: 0.0003
# Epoch [901/1100], Train Loss: 0.0003, Valid Loss: 0.0003
# Epoch [911/1100], Train Loss: 0.0003, Valid Loss: 0.0003
# Epoch [921/1100], Train Loss: 0.0003, Valid Loss: 0.0003
# Epoch [931/1100], Train Loss: 0.0003, Valid Loss: 0.0003
# Epoch [941/1100], Train Loss: 0.0003, Valid Loss: 0.0003
# Epoch [951/1100], Train Loss: 0.0003, Valid Loss: 0.0003
# Epoch [961/1100], Train Loss: 0.0003, Valid Loss: 0.0003
# Epoch [971/1100], Train Loss: 0.0003, Valid Loss: 0.0003
# Epoch [981/1100], Train Loss: 0.0003, Valid Loss: 0.0003
# Epoch [991/1100], Train Loss: 0.0003, Valid Loss: 0.0003
# Epoch [1001/1100], Train Loss: 0.0003, Valid Loss: 0.0003
# Epoch [1011/1100], Train Loss: 0.0003, Valid Loss: 0.0003
# Epoch [1021/1100], Train Loss: 0.0003, Valid Loss: 0.0003
# Epoch [1031/1100], Train Loss: 0.0003, Valid Loss: 0.0003
# Epoch [1041/1100], Train Loss: 0.0003, Valid Loss: 0.0003
# Epoch [1051/1100], Train Loss: 0.0003, Valid Loss: 0.0003
# Epoch [1061/1100], Train Loss: 0.0003, Valid Loss: 0.0003
# Epoch [1071/1100], Train Loss: 0.0003, Valid Loss: 0.0003
# Epoch [1081/1100], Train Loss: 0.0003, Valid Loss: 0.0003
# Epoch [1091/1100], Train Loss: 0.0003, Valid Loss: 0.0003

# %%
from sklearn.metrics import mean_squared_error
# Test the model
model.eval()
test_predict = model(testX)

test_predict_inv = sc.inverse_transform(test_predict.cpu().detach().numpy())
testY_inv = sc.inverse_transform(testY.cpu().detach().numpy())

test_score = np.sqrt(mean_squared_error(testY_inv, test_predict_inv))
print("Test RMSE Score: %.2f" % test_score)
# Out:
# Test RMSE Score: 16.91

# %%
import matplotlib.pyplot as plt

# make predictions
predY_test = model(testX)
predY_val = model(valX)

# invert scaling for forecast
predY_test_inv = sc.inverse_transform(predY_test.cpu().detach().numpy())
predY_val_inv = sc.inverse_transform(predY_val.cpu().detach().numpy())
testY_inv = sc.inverse_transform(testY.cpu().detach().numpy())
# plot 1
plt.plot(special_data, label='True Data')
plt.plot(special_data.index[-len(predY_test_inv)- val_size: - val_size], predY_test_inv, label='Test predicted Data')
plt.plot(special_data.index[-len(predY_val_inv):], predY_val_inv, label='Val predicted Data')
plt.axvline(x=special_data.index[-len(predY_test_inv)- val_size], c='r', linestyle='--')
plt.legend()
plt.show()
# plot 2
plt.plot(special_data.index[-len(predY_test_inv)- val_size:], special_data.Price[-len(predY_test_inv)- val_size:], label='True Data')
plt.plot(special_data.index[-len(predY_test_inv)- val_size: - val_size], predY_test_inv, label='Test predicted Data')
plt.plot(special_data.index[-len(predY_val_inv):], predY_val_inv, label='Val predicted Data')
plt.axvline(x=special_data.index[-len(predY_test_inv)- val_size], c='r', linestyle='--')
plt.legend()
plt.show()
