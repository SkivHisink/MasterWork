# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(rc={'figure.figsize':(14,7)})

# %%
#load data
data = pd.read_csv("..\..\..\Data\Day\S&P 500 Historical Data00-20Ffill.csv")

# %%
#transform data
data = data.replace(",", "", regex=True)
data.Date = pd.to_datetime(data.Date)
data = data.sort_values(by=["Date"])
data.set_index('Date')
data.Price = data.Price.astype(float)
data.High = data.High.astype(float)
data.Low = data.Low.astype(float)
data.Open = data.Open.astype(float)
data["Vol."] = data["Vol."].astype(float)

# %%
data.head()
# Out:
#         Date   Price    Open    High     Low  Vol. Change %
# 0 2000-01-03  1455.2  1469.2  1478.0  1438.4   NaN   -0.95%
# 1 2000-01-04  1399.4  1455.2  1455.2  1397.4   NaN   -3.83%
# 2 2000-01-05  1402.1  1399.4  1413.3  1377.7   NaN    0.19%
# 3 2000-01-06  1403.5  1402.1  1411.9  1392.0   NaN    0.10%
# 4 2000-01-07  1441.5  1403.5  1441.5  1400.5   NaN    2.71%

# %%
data.index = data.index[::-1]

# %%
data.head()
# Out:
#            Date   Price    Open    High     Low  Vol. Change %
# 7255 2000-01-03  1455.2  1469.2  1478.0  1438.4   NaN   -0.95%
# 7254 2000-01-04  1399.4  1455.2  1455.2  1397.4   NaN   -3.83%
# 7253 2000-01-05  1402.1  1399.4  1413.3  1377.7   NaN    0.19%
# 7252 2000-01-06  1403.5  1402.1  1411.9  1392.0   NaN    0.10%
# 7251 2000-01-07  1441.5  1403.5  1441.5  1400.5   NaN    2.71%

# %%
special_data = data[(data['Date'] > '2010-01-01') & (data['Date'] < '2014-01-01')]
special_data.index = data.index[:len(special_data)]

# %%
special_data.head()
# Out:
#            Date    Price     Open     High      Low  Vol. Change %
# 7255 2010-01-02  1115.10  1126.60  1127.64  1114.81   NaN   -1.00%
# 7254 2010-01-03  1115.10  1126.60  1127.64  1114.81   NaN   -1.00%
# 7253 2010-01-04  1132.99  1116.56  1133.87  1116.56   NaN    1.60%
# 7252 2010-01-05  1136.52  1132.66  1136.63  1129.66   NaN    0.31%
# 7251 2010-01-06  1137.14  1135.71  1139.19  1133.95   NaN    0.05%

# %%
#change indexes
special_data.set_index('Date', inplace=True)

# %%
special_data = special_data.drop(columns=['Open', 'High', 'Low', 'Vol.', 'Change %'])

# %%
special_data.head()
# Out:
#               Price
# Date
# 2010-01-02  1115.10
# 2010-01-03  1115.10
# 2010-01-04  1132.99
# 2010-01-05  1136.52
# 2010-01-06  1137.14

# %%
plt.plot(special_data)

# %%
special_data.rename(columns={'Price': 'Close'}, inplace=True)

# %%
from scalecast.Forecaster import Forecaster
f = Forecaster(y = special_data['Close'], 
               current_dates = special_data.index)

# %%
# EDA
f.plot_acf()
plt.show()
f.plot_pacf()
plt.show()
f.seasonal_decompose().plot()
plt.show()
stat, pval, _, _, _, _ = f.adf_test(full_res=True)
print(stat)
print(pval)
# Out:
# 0.4246268544525403
# 0.9823929006106872

# %%
# Forecast
f.manual_forecast(order=(2,1,1),seasonal_order=(2,1,1,12),call_me='arima2')

# View test results
f.plot_test_set(ci = True,models='arima2')
plt.title('ARIMA Test-Set Performance',size=14)
plt.show()

# View forecast results
f.plot(ci = True, models = 'arima2')
plt.title('ARIMA Forecast Performance',size=14)
plt.show()

# See summary stats
f.regr.summary()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scalecast\_utils.py:25, in _developer_utils.descriptive_assert(statement, ErrorType, error_message)
#      24 try:
# ---> 25     assert statement
#      26 except AssertionError:
#
# AssertionError:
#
# During handling of the above exception, another exception occurred:
#
# ForecastError                             Traceback (most recent call last)
# Cell In[16], line 2
#       1 # Forecast
# ----> 2 f.manual_forecast(order=(2,1,1),seasonal_order=(2,1,1,12),call_me='arima2')
#       4 # View test results
#       5 f.plot_test_set(ci = True,models='arima2')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scalecast\_Forecaster_parent.py:738, in Forecaster_parent.manual_forecast(self, call_me, dynamic_testing, test_again, bank_history, **kwargs)
#     706 """ Manually forecasts with the hyperparameters, Xvars, and normalizer selection passed as keywords.
#     707 See https://scalecast.readthedocs.io/en/latest/Forecaster/_forecast.html.
#     708
#    (...)
#     730 >>> f.manual_forecast(alpha=.5)
#     731 """
#     732 _developer_utils.descriptive_assert(
#     733     isinstance(call_me, str) | (call_me is None),
#     734     ValueError,
#     735     "call_me must be a str type or None.",
#     736 )
# --> 738 _developer_utils.descriptive_assert(
#     739     len(self.future_dates) > 0,
#     740     ForecastError,
#     741     "Before calling a model, please make sure you have generated future dates"
#     742     " by calling generate_future_dates(), set_last_future_date(), or ingest_Xvars_df(use_future_dates=True).",
#     743 )
#     745 self._clear_the_deck() # delete some attributes from last model
#     747 self.dynamic_testing = dynamic_testing
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scalecast\_utils.py:27, in _developer_utils.descriptive_assert(statement, ErrorType, error_message)
#      25     assert statement
#      26 except AssertionError:
# ---> 27     raise ErrorType(error_message)
#
# ForecastError: Before calling a model, please make sure you have generated future dates by calling generate_future_dates(), set_last_future_date(), or ingest_Xvars_df(use_future_dates=True).

# %%
# Разделение данных на train и test
train_size = int(0.9 * len(special_data))  # 80% данных для обучения
train_data = pd.DataFrame({
    'ds': special_data.iloc[:train_size].index,
    'y' : special_data.iloc[:train_size].Close})
test_data = pd.DataFrame({
    'ds': special_data.iloc[train_size:].index,
    'y' : special_data.iloc[train_size:].Close})

# %%
train_size
# Out:
# 1314

# %%
from prophet import Prophet

# Создание и обучение модели Prophet
model = Prophet(daily_seasonality = False)  # Указываем, что у нас есть ежедневная сезонность
model.fit(train_data.reset_index())
# Out:
# 20:10:46 - cmdstanpy - INFO - Chain [1] start processing
# 20:10:46 - cmdstanpy - INFO - Chain [1] done processing

# %%
# Создание фрейма для прогнозирования
future = pd.DataFrame(index = test_data.index)
future['ds'] = test_data.index

# %%
# Получение прогнозов
forecast = model.predict(future)

# %%
# Визуализация результатов
fig = plt.figure(figsize=(10, 6))
plt.plot(train_data.index, train_data['y'], label='Обучающие данные')
plt.plot(test_data.index, test_data['y'], label='Реальные данные')
plt.plot(test_data.index, forecast['yhat'], label='Прогноз')
plt.fill_between(test_data.index, forecast['yhat_lower'], forecast['yhat_upper'], color='gray', alpha = 0.2)
plt.xlabel('Дата')
plt.ylabel('Цена')
plt.legend()
plt.xticks(rotation=45)  # поворот лейблов на 45 градусов
plt.show()

# %%
# Визуализация результатов
fig = plt.figure(figsize=(10, 6))
plt.plot(test_data.index, test_data['y'], label='Реальные данные')
plt.plot(test_data.index, forecast['yhat'], label='Прогноз')
plt.fill_between(test_data.index, forecast['yhat_lower'], forecast['yhat_upper'], color='gray', alpha = 0.2)
plt.xlabel('Дата')
plt.ylabel('Цена')
plt.legend()
plt.show()

# %%
def calculate_metrics(array1, array2):
    # Проверка на совпадение длин массивов
    if len(array1) != len(array2):
        raise ValueError("Длины массивов должны совпадать")

    # Вычисление отклонений
    deviations = np.abs(np.array(array1) - np.array(array2))

    # Минимальное и максимальное отклонение
    min_deviation = np.min(deviations)
    max_deviation = np.max(deviations)

    # Процентное минимальное и максимальное отклонение
    min_deviation_percentage = min_deviation / np.max(np.abs(array1)) * 100
    max_deviation_percentage = max_deviation / np.max(np.abs(array1)) * 100
    
    # MAPE (Mean Absolute Percentage Error)
    mape = np.mean(deviations / np.abs(array1)) * 100

    return min_deviation, max_deviation, min_deviation_percentage, max_deviation_percentage, mape

# %%
min_dev, max_dev, min_dev_percentage, max_dev_percentage, mape = calculate_metrics(test_data['y'].values, forecast['yhat'])

print(f"Минимальное отклонение: {min_dev}")
print(f"Максимальное отклонение: {max_dev}")
print(f"Процентное минимальное отклонение: {min_dev_percentage:.2f}%")
print(f"Процентное максимальное отклонение: {max_dev_percentage:.2f}%")
print(f"MAPE: {mape:.2f}%")
# Out:
# Минимальное отклонение: 2.649083458907853
# Максимальное отклонение: 127.15416884785691
# Процентное минимальное отклонение: 0.14%
# Процентное максимальное отклонение: 6.88%
# MAPE: 2.94%

# %%
len(special_data)
# Out:
# 1460

# %%
len(train_data['y'])
# Out:
# 1314

# %%
len(test_data['y'])
# Out:
# 146

# %%
def save_array_to_txt(array, filename):
    # Преобразуем одномерный массив в двумерный массив с одним столбцом
    array = np.reshape(array, (len(array), 1))
    
    # Сохраняем массив в текстовый файл
    np.savetxt(filename, array, fmt='%.3f')  # fmt='%d' указывает формат данных (целые числа)

# %%
save_array_to_txt(forecast['yhat'].values, "prop90ffill.txt")
