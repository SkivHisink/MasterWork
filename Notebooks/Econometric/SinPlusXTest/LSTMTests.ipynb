# %%
import pandas as pd
import numpy as np
from prophet import Prophet
import matplotlib.pyplot as plt

start_date = '2019-01-01'
end_date = '2022-01-01'

dates = pd.date_range(start=start_date, end=end_date, freq='D')
unix_dates = np.array([int(pd.Timestamp(d).timestamp()) for d in dates])
# Recreate a DatetimeIndex with a specific frequency

freq = 'D'  # Monthly frequency
date_rng = pd.date_range(start=start_date, end=end_date, freq=freq)

prices = np.sin(unix_dates)

for i in range(len(prices)):
    prices[i] = prices[i] + float(i) / 50

data = pd.DataFrame({'ds': date_rng, 'y': prices})

# %%
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf
import matplotlib.pyplot as plt
# Построение графика автокорреляционной функции (ACF)
fig, ax = plt.subplots(figsize=(10, 6))
plot_acf(prices, lags=30, ax=ax)  # Установите значение lags в соответствии с вашими потребностями
plt.xlabel('Лаги')
plt.ylabel('Корреляция')
plt.title('График ACF')
plt.show()
# Построение графика частичной автокорреляционной функции (PACF)
fig, ax = plt.subplots(figsize=(10, 6))
plot_pacf(prices, lags=30, ax=ax)  # Установите значение lags в соответствии с вашими потребностями
plt.xlabel('Лаги')
plt.ylabel('Частичная корреляция')
plt.title('График PACF')
plt.show()
# Out:
# C:\Users\Skiv2\AppData\Roaming\Python\Python38\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
from statsmodels.tsa.stattools import adfuller

result = adfuller(prices)
print('ADF Statistic:', result[0])
print('p-value:', result[1])
# Out:
# ADF Statistic: -0.11817635700894347
# p-value: 0.9475977329255294

# %%
# %matplotlib inline

import glob
from platform import python_version
import pandas as pd
import matplotlib
import numpy as np
import pandas as pd
import sklearn
import torch
import matplotlib.pyplot as plt

# %%
print("python version==%s" % python_version())
print("pandas==%s" % pd.__version__)
print("numpy==%s" % np.__version__)
print("sklearn==%s" % sklearn.__version__)
print("torch==%s" % torch.__version__)
print("matplotlib==%s" % matplotlib.__version__)
# Out:
# python version==3.8.10
# pandas==1.5.1
# numpy==1.23.4
# sklearn==1.1.3
# torch==1.13.0+cu117
# matplotlib==3.6.2

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)
# Out:
# Using device: cuda

# %%
plt.plot(prices)

# %%
model_data = pd.DataFrame({'Price': prices, 'Date': date_rng})
model_data = model_data.set_index('Date', inplace = False)
model_data.head(10)
# Out:
#                Price
# Date
# 2019-01-01 -0.885371
# 2019-01-02 -0.900145
# 2019-01-03 -0.908861
# 2019-01-04 -0.911331
# 2019-01-05 -0.907407
# 2019-01-06 -0.896982
# 2019-01-07 -0.879994
# 2019-01-08 -0.856423
# 2019-01-09 -0.826292
# 2019-01-10 -0.789668

# %%
from torch.autograd import Variable
from sklearn.preprocessing import MinMaxScaler

def sliding_windows(data, seq_length):
    x = []
    y = []

    for i in range(len(data)-seq_length-1):
        _x = data[i:(i+seq_length)]
        _y = data[i+seq_length]
        x.append(_x)
        y.append(_y)

    return np.array(x),np.array(y)

sc = MinMaxScaler()
training_data = sc.fit_transform(model_data)

seq_length = 100
x, y = sliding_windows(training_data, seq_length)

train_size = int(len(y) * 0.7)
val_size = 100
test_size = len(y) - train_size - val_size

dataX = Variable(torch.Tensor(np.array(x)).to(device))
dataY = Variable(torch.Tensor(np.array(y)).to(device))

trainX = Variable(torch.Tensor(np.array(x[0:train_size])).to(device))
trainY = Variable(torch.Tensor(np.array(y[0:train_size])).to(device))

testX = Variable(torch.Tensor(np.array(x[train_size:(len(x) - val_size)])).to(device))
testY = Variable(torch.Tensor(np.array(y[train_size:(len(y) - val_size)])).to(device))

valX = Variable(torch.Tensor(np.array(x[(len(x) - val_size):len(x)])).to(device))
valY = Variable(torch.Tensor(np.array(y[(len(x) - val_size):len(y)])).to(device))

# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

class TimeSeriesDataset(Dataset):
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __len__(self):
        return len(self.x)

    def __getitem__(self, idx):
        return self.x[idx], self.y[idx]

train_dataset = TimeSeriesDataset(trainX, trainY)
test_dataset = TimeSeriesDataset(testX, testY)
val_dataset = TimeSeriesDataset(valX, valY)

train_loader = DataLoader(train_dataset, batch_size = 64, shuffle = False)
test_loader = DataLoader(test_dataset, batch_size = 64, shuffle = False)
val_loader = DataLoader(val_dataset, batch_size = 64, shuffle = False)

# %%
import torch.nn as nn

class LSTM(nn.Module):

    def __init__(self, num_classes, input_size, hidden_size, num_layers):
        super(LSTM, self).__init__()
        
        self.num_classes = num_classes
        self.num_layers = num_layers
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.seq_length = seq_length
        
        self.lstm = nn.LSTM(input_size = input_size, hidden_size = hidden_size,
                            num_layers = num_layers, batch_first=True)
        
        self.fc = nn.Linear(hidden_size, num_classes)

    def forward(self, x):
        h_0 = Variable(torch.zeros(
            self.num_layers, x.size(0), self.hidden_size).to(device))
        
        c_0 = Variable(torch.zeros(
            self.num_layers, x.size(0), self.hidden_size).to(device))
        
        # Propagate input through LSTM
        ula, (h_out, _) = self.lstm(x, (h_0, c_0))
        
        h_out = h_out.view(-1, self.hidden_size)
        
        out = self.fc(h_out)
        
        return out

# %%
num_epochs = 1100
learning_rate = 0.001

input_size = 1
hidden_size = 64 # need to find correct value; 40 small, 64 norm, 100 a lot
num_layers = 1

num_classes = 1

model = LSTM(num_classes, input_size, hidden_size, num_layers).to(device)

# Define loss and optimizer
criterion = torch.nn.MSELoss()    # mean-squared error for regression
optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate)
#optimizer = torch.optim.SGD(lstm.parameters(), lr = learning_rate)

train_loss = []
valid_loss = []

for epoch in range(num_epochs):
    # set the model to train mode
    model.train()

    # forward pass
    output = model(trainX)
    loss = criterion(output, trainY)

    # backward pass and optimize
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    # calculate training loss
    train_loss.append(loss.item())

    # set the model to evaluation mode
    model.eval()

    # calculate validation loss
    with torch.no_grad():
        output = model(testX)
        loss = criterion(output, testY)
        valid_loss.append(loss.item())

    # print progress
    if epoch % 10 == 0:
        print('Epoch [{}/{}], Train Loss: {:.4f}, Valid Loss: {:.4f}'.format(
            epoch+1, num_epochs, train_loss[-1], valid_loss[-1]))

# plot train and validation loss
plt.plot(train_loss, label='Train Loss')
plt.plot(valid_loss, label='Validation Loss')
plt.legend()
plt.show()
# Out:
# Epoch [1/1100], Train Loss: 0.3201, Valid Loss: 0.8441
# Epoch [11/1100], Train Loss: 0.1647, Valid Loss: 0.5218
# Epoch [21/1100], Train Loss: 0.0316, Valid Loss: 0.0155
# Epoch [31/1100], Train Loss: 0.0239, Valid Loss: 0.1539
# Epoch [41/1100], Train Loss: 0.0177, Valid Loss: 0.0860
# Epoch [51/1100], Train Loss: 0.0161, Valid Loss: 0.0615
# Epoch [61/1100], Train Loss: 0.0137, Valid Loss: 0.0700
# Epoch [71/1100], Train Loss: 0.0108, Valid Loss: 0.0367
# Epoch [81/1100], Train Loss: 0.0074, Valid Loss: 0.0269
# Epoch [91/1100], Train Loss: 0.0036, Valid Loss: 0.0058
# Epoch [101/1100], Train Loss: 0.0011, Valid Loss: 0.0036
# Epoch [111/1100], Train Loss: 0.0013, Valid Loss: 0.0096
# Epoch [121/1100], Train Loss: 0.0009, Valid Loss: 0.0015
# Epoch [131/1100], Train Loss: 0.0009, Valid Loss: 0.0008
# Epoch [141/1100], Train Loss: 0.0008, Valid Loss: 0.0012
# Epoch [151/1100], Train Loss: 0.0007, Valid Loss: 0.0011
# Epoch [161/1100], Train Loss: 0.0007, Valid Loss: 0.0006
# Epoch [171/1100], Train Loss: 0.0006, Valid Loss: 0.0005
# Epoch [181/1100], Train Loss: 0.0006, Valid Loss: 0.0004
# Epoch [191/1100], Train Loss: 0.0005, Valid Loss: 0.0004
# Epoch [201/1100], Train Loss: 0.0005, Valid Loss: 0.0004
# Epoch [211/1100], Train Loss: 0.0005, Valid Loss: 0.0005
# Epoch [221/1100], Train Loss: 0.0004, Valid Loss: 0.0006
# Epoch [231/1100], Train Loss: 0.0004, Valid Loss: 0.0007
# Epoch [241/1100], Train Loss: 0.0004, Valid Loss: 0.0008
# Epoch [251/1100], Train Loss: 0.0004, Valid Loss: 0.0009
# Epoch [261/1100], Train Loss: 0.0004, Valid Loss: 0.0010
# Epoch [271/1100], Train Loss: 0.0004, Valid Loss: 0.0011
# Epoch [281/1100], Train Loss: 0.0004, Valid Loss: 0.0012
# Epoch [291/1100], Train Loss: 0.0004, Valid Loss: 0.0013
# Epoch [301/1100], Train Loss: 0.0004, Valid Loss: 0.0013
# Epoch [311/1100], Train Loss: 0.0004, Valid Loss: 0.0014
# Epoch [321/1100], Train Loss: 0.0003, Valid Loss: 0.0014
# Epoch [331/1100], Train Loss: 0.0003, Valid Loss: 0.0014
# Epoch [341/1100], Train Loss: 0.0003, Valid Loss: 0.0014
# Epoch [351/1100], Train Loss: 0.0003, Valid Loss: 0.0014
# Epoch [361/1100], Train Loss: 0.0003, Valid Loss: 0.0013
# Epoch [371/1100], Train Loss: 0.0003, Valid Loss: 0.0013
# Epoch [381/1100], Train Loss: 0.0003, Valid Loss: 0.0013
# Epoch [391/1100], Train Loss: 0.0003, Valid Loss: 0.0013
# Epoch [401/1100], Train Loss: 0.0003, Valid Loss: 0.0012
# Epoch [411/1100], Train Loss: 0.0003, Valid Loss: 0.0012
# Epoch [421/1100], Train Loss: 0.0003, Valid Loss: 0.0012
# Epoch [431/1100], Train Loss: 0.0003, Valid Loss: 0.0011
# Epoch [441/1100], Train Loss: 0.0003, Valid Loss: 0.0011
# Epoch [451/1100], Train Loss: 0.0003, Valid Loss: 0.0011
# Epoch [461/1100], Train Loss: 0.0003, Valid Loss: 0.0010
# Epoch [471/1100], Train Loss: 0.0003, Valid Loss: 0.0010
# Epoch [481/1100], Train Loss: 0.0003, Valid Loss: 0.0010
# Epoch [491/1100], Train Loss: 0.0003, Valid Loss: 0.0009
# Epoch [501/1100], Train Loss: 0.0003, Valid Loss: 0.0009
# Epoch [511/1100], Train Loss: 0.0003, Valid Loss: 0.0009
# Epoch [521/1100], Train Loss: 0.0002, Valid Loss: 0.0008
# Epoch [531/1100], Train Loss: 0.0002, Valid Loss: 0.0008
# Epoch [541/1100], Train Loss: 0.0002, Valid Loss: 0.0008
# Epoch [551/1100], Train Loss: 0.0002, Valid Loss: 0.0007
# Epoch [561/1100], Train Loss: 0.0002, Valid Loss: 0.0007
# Epoch [571/1100], Train Loss: 0.0002, Valid Loss: 0.0007
# Epoch [581/1100], Train Loss: 0.0002, Valid Loss: 0.0007
# Epoch [591/1100], Train Loss: 0.0002, Valid Loss: 0.0006
# Epoch [601/1100], Train Loss: 0.0002, Valid Loss: 0.0006
# Epoch [611/1100], Train Loss: 0.0002, Valid Loss: 0.0006
# Epoch [621/1100], Train Loss: 0.0002, Valid Loss: 0.0006
# Epoch [631/1100], Train Loss: 0.0002, Valid Loss: 0.0006
# Epoch [641/1100], Train Loss: 0.0001, Valid Loss: 0.0006
# Epoch [651/1100], Train Loss: 0.0001, Valid Loss: 0.0006
# Epoch [661/1100], Train Loss: 0.0001, Valid Loss: 0.0005
# Epoch [671/1100], Train Loss: 0.0001, Valid Loss: 0.0005
# Epoch [681/1100], Train Loss: 0.0001, Valid Loss: 0.0010
# Epoch [691/1100], Train Loss: 0.0001, Valid Loss: 0.0004
# Epoch [701/1100], Train Loss: 0.0001, Valid Loss: 0.0002
# Epoch [711/1100], Train Loss: 0.0001, Valid Loss: 0.0002
# Epoch [721/1100], Train Loss: 0.0001, Valid Loss: 0.0002
# Epoch [731/1100], Train Loss: 0.0001, Valid Loss: 0.0001
# Epoch [741/1100], Train Loss: 0.0001, Valid Loss: 0.0001
# Epoch [751/1100], Train Loss: 0.0001, Valid Loss: 0.0001
# Epoch [761/1100], Train Loss: 0.0001, Valid Loss: 0.0001
# Epoch [771/1100], Train Loss: 0.0001, Valid Loss: 0.0001
# Epoch [781/1100], Train Loss: 0.0001, Valid Loss: 0.0001
# Epoch [791/1100], Train Loss: 0.0001, Valid Loss: 0.0001
# Epoch [801/1100], Train Loss: 0.0000, Valid Loss: 0.0001
# Epoch [811/1100], Train Loss: 0.0000, Valid Loss: 0.0001
# Epoch [821/1100], Train Loss: 0.0000, Valid Loss: 0.0001
# Epoch [831/1100], Train Loss: 0.0000, Valid Loss: 0.0001
# Epoch [841/1100], Train Loss: 0.0000, Valid Loss: 0.0001
# Epoch [851/1100], Train Loss: 0.0000, Valid Loss: 0.0001
# Epoch [861/1100], Train Loss: 0.0000, Valid Loss: 0.0001
# Epoch [871/1100], Train Loss: 0.0000, Valid Loss: 0.0001
# Epoch [881/1100], Train Loss: 0.0000, Valid Loss: 0.0001
# Epoch [891/1100], Train Loss: 0.0000, Valid Loss: 0.0001
# Epoch [901/1100], Train Loss: 0.0000, Valid Loss: 0.0001
# Epoch [911/1100], Train Loss: 0.0000, Valid Loss: 0.0001
# Epoch [921/1100], Train Loss: 0.0000, Valid Loss: 0.0001
# Epoch [931/1100], Train Loss: 0.0000, Valid Loss: 0.0002
# Epoch [941/1100], Train Loss: 0.0000, Valid Loss: 0.0002
# Epoch [951/1100], Train Loss: 0.0000, Valid Loss: 0.0002
# Epoch [961/1100], Train Loss: 0.0000, Valid Loss: 0.0003
# Epoch [971/1100], Train Loss: 0.0000, Valid Loss: 0.0003
# Epoch [981/1100], Train Loss: 0.0001, Valid Loss: 0.0002
# Epoch [991/1100], Train Loss: 0.0000, Valid Loss: 0.0007
# Epoch [1001/1100], Train Loss: 0.0000, Valid Loss: 0.0006
# Epoch [1011/1100], Train Loss: 0.0000, Valid Loss: 0.0007
# Epoch [1021/1100], Train Loss: 0.0000, Valid Loss: 0.0007
# Epoch [1031/1100], Train Loss: 0.0000, Valid Loss: 0.0006
# Epoch [1041/1100], Train Loss: 0.0000, Valid Loss: 0.0005
# Epoch [1051/1100], Train Loss: 0.0000, Valid Loss: 0.0005
# Epoch [1061/1100], Train Loss: 0.0000, Valid Loss: 0.0005
# Epoch [1071/1100], Train Loss: 0.0001, Valid Loss: 0.0003
# Epoch [1081/1100], Train Loss: 0.0000, Valid Loss: 0.0006
# Epoch [1091/1100], Train Loss: 0.0000, Valid Loss: 0.0012

# %%
from sklearn.metrics import mean_squared_error
# Test the model
model.eval()
test_predict = model(testX)

test_predict_inv = sc.inverse_transform(test_predict.cpu().detach().numpy())
testY_inv = sc.inverse_transform(testY.cpu().detach().numpy())

test_score = np.sqrt(mean_squared_error(testY_inv, test_predict_inv))
print("Test RMSE Score: %.2f" % test_score)
# Out:
# Test RMSE Score: 0.72

# %%
import matplotlib.pyplot as plt

# make predictions
predY_test = model(testX)
predY_val = model(valX)

# invert scaling for forecast
predY_test_inv = sc.inverse_transform(predY_test.cpu().detach().numpy())
predY_val_inv = sc.inverse_transform(predY_val.cpu().detach().numpy())
testY_inv = sc.inverse_transform(testY.cpu().detach().numpy())
# plot 1
plt.plot(model_data, label='True Data')
plt.plot(model_data.index[-len(predY_test_inv)- val_size: - val_size], predY_test_inv, label='Test predicted Data')
plt.plot(model_data.index[-len(predY_val_inv):], predY_val_inv, label='Val predicted Data')
plt.axvline(x=model_data.index[-len(predY_test_inv)- val_size], c='r', linestyle='--')
plt.legend()
plt.show()
# plot 2
plt.plot(model_data.index[-len(predY_test_inv)- val_size:], model_data.Price[-len(predY_test_inv)- val_size:], label='True Data')
plt.plot(model_data.index[-len(predY_test_inv)- val_size: - val_size], predY_test_inv, label='Test predicted Data')
plt.plot(model_data.index[-len(predY_val_inv):], predY_val_inv, label='Val predicted Data')
plt.axvline(x=model_data.index[-len(predY_test_inv)- val_size], c='r', linestyle='--')
plt.legend()
plt.show()

# %%
plt.plot(model_data.Price[-len(predY_test_inv)- val_size: - val_size].values - [item for sublist in predY_test_inv for item in sublist])

# %%
model_data.Price[-len(predY_test_inv)- val_size: - val_size].values
# Out:
# array([15.8390455 , 15.93991838, 16.04105513, 16.1419216 , 16.24198544,
#        16.34071957, 16.43760568, 16.53213761, 16.62382471, 16.71219504,
#        16.79679851, 16.87720982, 16.95303128, 17.02389541, 17.08946735,
#        17.14944711, 17.20357148, 17.25161582, 17.2933955 , 17.32876716,
#        17.35762959, 17.37992446, 17.39563664, 17.40479438, 17.40746905,
#        17.4037747 , 17.39386732, 17.3779438 , 17.35624062, 17.32903232,
#        17.29662968, 17.25937769, 17.21765323, 17.17186265, 17.12243907,
#        17.06983951, 17.01454191, 16.95704195, 16.89784985, 16.83748693,
#        16.77648223, 16.71536903, 16.65468131, 16.59495025, 16.53670072,
#        16.48044787, 16.42669368, 16.37592368, 16.32860376, 16.28517711,
#        16.24606127, 16.21164541, 16.18228776, 16.15831326, 16.14001139,
#        16.1276343 , 16.12139513, 16.12146662, 16.12797997, 16.14102396,
#        16.16064438, 16.18684373, 16.2195812 , 16.25877294, 16.3042926 ,
#        16.35597218, 16.41360314, 16.47693774, 16.54569069, 16.61954106,
#        16.69813434, 16.78108479, 16.867978  , 16.95837361, 17.05180818,
#        17.14779829, 17.24584367, 17.34543055, 17.44603498, 17.54712634,
#        17.64817078, 17.74863478, 17.84798863, 17.94570993, 18.04128702,
#        18.13422237, 18.22403583, 18.31026781, 18.3924823 , 18.47026971,
#        18.54324963, 18.61107329, 18.67342584, 18.73002849, 18.78064025,
#        18.82505962, 18.86312584, 18.89471997, 18.91976568, 18.93822977,
#        18.95012233, 18.95549675, 18.95444931, 18.94711856, 18.93368442,
#        18.91436701, 18.88942516, 18.85915472, 18.82388663, 18.78398473,
#        18.73984337, 18.6918848 , 18.64055641, 18.58632776, 18.5296875 ,
#        18.47114019, 18.4112029 , 18.35040188, 18.28926906, 18.22833854,
#        18.16814311, 18.10921071, 18.05206096, 17.99720175, 17.9451259 ,
#        17.89630789, 17.85120076, 17.81023313, 17.77380635, 17.74229189,
#        17.71602888, 17.69532188, 17.68043887, 17.67160949, 17.66902353,
#        17.67282967, 17.68313453, 17.70000192, 17.72345248, 17.75346348,
#        17.78996902, 17.83286044, 17.88198704, 17.93715709, 17.99813904,
#        18.0646631 , 18.13642301, 18.21307801, 18.29425514, 18.37955166,
#        18.4685377 , 18.56075913, 18.65574049, 18.75298817, 18.85199363,
#        18.95223678, 19.05318935, 19.15431841, 19.25508989, 19.35497205,
#        19.45343901, 19.54997421, 19.64407381, 19.73524999, 19.8230342 ,
#        19.90698018, 19.98666699, 20.06170168, 20.13172197, 20.19639854,
#        20.25543729, 20.30858123, 20.35561216, 20.39635212, 20.43066459,
#        20.45845535, 20.4796731 , 20.49430983, 20.50240084, 20.50402454,
#        20.4993019 , 20.48839568, 20.47150933, 20.44888568, 20.42080533,
#        20.38758481, 20.34957447, 20.30715621, 20.26074093, 20.21076586,
#        20.15769166, 20.10199938, 20.04418733, 19.98476775, 19.92426348,
#        19.86320448, 19.80212439, 19.74155697, 19.6820326 ])
