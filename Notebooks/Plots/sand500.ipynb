# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Загрузка данных из CSV-файла
day_data = pd.read_csv("..\..\Data\Day\sand500_Linear.csv")
week_data = pd.read_csv("..\..\Data\Week\sand500_Linear.csv")
month_data = pd.read_csv("..\..\Data\Month\sand500_Linear.csv")

# %%
# Построение диаграммы рассеяния
plt.figure(figsize=(8, 6))
plt.plot(day_data['Date'], day_data['Close'], label='Ежедневные данные')
plt.plot(week_data['Date'], week_data['Close'], label='Еженедельные данные')
plt.plot(month_data['Date'], month_data['Close'], label='Ежемесячные данные')
plt.xlabel('Дата')
plt.ylabel('Цена')

# Уменьшение количества меток на оси x
plt.xticks(rotation=45, ha='right')
plt.xticks(day_data['Date'][::len(day_data) // 10])

plt.legend()
plt.show()

# %%
# Построение диаграммы рассеяния
plt.figure(figsize = (8, 6))
plt.scatter(day_data['Date'], 
         day_data['Close'],
         s = 8,
         edgecolors='blue',
         facecolors='red',
         label = 'Ежедневные данные')

plt.xlabel('Дата')
plt.ylabel('Пункты')

# Уменьшение количества меток на оси x
plt.xticks(rotation = 45, ha = 'right')
plt.xticks(day_data['Date'][::len(day_data) // 10])

plt.legend()
plt.show()

# %%
# Построение диаграммы рассеяния
plt.figure(figsize = (8, 6))

plt.scatter(week_data['Date'], 
         week_data['Close'],
         s = 8,
         edgecolors='blue',
         facecolors='red',
         label = 'Еженедельные данные')

plt.xlabel('Дата')
plt.ylabel('Пункты')

# Уменьшение количества меток на оси x
plt.xticks(rotation = 45, ha = 'right')
plt.xticks(week_data['Date'][::len(week_data) // 10])

plt.legend()
plt.show()

# %%
# Построение диаграммы рассеяния
plt.figure(figsize = (8, 6))

plt.scatter(month_data['Date'], 
         month_data['Close'],
         s = 8,
         edgecolors='blue',
         facecolors='red',
         label = 'Ежемесячные данные')

plt.xlabel('Дата')
plt.ylabel('Пункты')

# Уменьшение количества меток на оси x
plt.xticks(rotation = 45, ha = 'right')
plt.xticks(month_data['Date'][::len(month_data) // 10])

plt.legend()
plt.show()
